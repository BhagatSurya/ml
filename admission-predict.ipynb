# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd 
import numpy as np 
from sklearn.preprocessing import StandardScaler 
from sklearn.linear_model  import Ridge,Lasso,RidgeCV, LassoCV, ElasticNet, ElasticNetCV, LinearRegression
from sklearn.model_selection import train_test_split
import statsmodels.api as sm 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('../input/admission-predict/Admission_Predict.csv')#loading or reading data

# %%
df

# %%
df.isnull().sum()#no null values

# %%
df.describe().T #statcis info

# %%
df.drop(labels='Serial No.',axis=1,inplace=True)#removing serial no from df

# %%
df

# %%
import seaborn as sns

# %% [markdown]
# **** finding distiputions in dataset

# %%
for i in df.columns:
    sns.displot(df, x=df[i])

# %%
df

# %%
y = df['Chance of Admit']
X =df.drop(columns = ['Chance of Admit'])

# %%
y#dependent varable

# %%
x #indepent varable

# %%
# finding relationships distuption btween indepent and depentent

# %%
sns.set_theme(style="darkgrid")
for data in x:
    sns.relplot(x=x[data],y=y)

# %% [markdown]
# Standardize features by removing the mean and scaling to unit variance.
#
# The standard score of a sample x is calculated as:
#
# z = (x - u) / s

# %% [markdown]
# # conveting x to Standardize

# %%
scaler =StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables = X_scaled

# we create a new data frame which will include all the VIFs
# note that each variable has its own variance inflation factor as this measure is variable specific (not model specific)
# we do not include categorical values for mulitcollinearity as they do not provide much information as numerical ones do
vif = pd.DataFrame()

# here we make use of the variance_inflation_factor, which will basically output the respective VIFs 
vif["VIF"] = [variance_inflation_factor(variables, i) for i in range(variables.shape[1])]
# Finally, I like to include names so it is easier to explore the result
vif["Features"] = X.columns

# %%
# THE VIF IS NOT MORE THRN (5) SO IT'S SO GOOD TO GO 
vif

# %%
x_train,x_test,y_train,y_test = train_test_split(X_scaled,y,test_size = 0.25,random_state=355)

# %%
print(y_train.shape)
print(y_test.shape)
print(X_train.shape)
print(X_test.shape)

# %%
#LINERREGRESSION 
regression = LinearRegression()

regression.fit(X_train,y_train)

# %%
regression.score(x_train,y_train)

# %%
regression.score(x_test,y_test)

# %%
#it seem's like over fitting but i checkied with l1 and l2 i am getting same
